# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Parnashree Gurav"
age = 21
city = "Mumbai"

print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Name: Parnashree Gurav
# Age: 21
# City: Mumbai

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
foods = ["Pizza", "Pasta", "Burger", "Momos"]

print("My favorite foods:")
print(foods)

# Accessing items
print("First food:", foods[0])
print("Last food:", foods[-1])
# Out:
# My favorite foods:
# ['Pizza', 'Pasta', 'Burger', 'Momos']
# First food: Pizza
# Last food: Momos

# %%
name = "Parnashree Gurav"
age = 21
city = "Mumbai"
skills = ["PowerBI", "SQL", "Python"]

print("----- BIO DATA -----")
print("Name:", name)
print("Age:", age)
print("City:", city)
print("Skills:", skills)
# Out:
# ----- BIO DATA -----
# Name: Parnashree Gurav
# Age: 21
# City: Mumbai
# Skills: ['PowerBI', 'SQL', 'Python']

# %%
# Personal Introduction Program

# Asking for user details
name = input("Enter your name: ")
age = input("Enter your age: ")
hobby = input("Enter your hobby: ")

# Displaying a friendly welcome message
print("\n---------- Welcome Message ----------")
print(f"Hello {name}! 👋")
print(f"You are {age} years old.")
print(f"It's cool that you enjoy {hobby}!")
print("Nice to meet you! 😊")
# Out:
# Enter your name:  Parnashree Gurav
# Enter your age:  21
# Enter your hobby:  Painting
# ---------- Welcome Message ----------
# Hello Parnashree Gurav! 👋
# You are 21 years old.
# It's cool that you enjoy Painting!
# Nice to meet you! 😊
